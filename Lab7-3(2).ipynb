# %%
#IMDB. 풀버전 코드는 아래에 있음 
import numpy as np
import tensorflow as tf
from tensorflow import keras

#학습용 데이터
imdb = keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

word_index = imdb.get_word_index()

# The first indices are reserved
word_index = {k:(v+3) for k,v in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2  # unknown
word_index["<UNUSED>"] = 3

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text) :
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

decode_review(train_data[4])


train_data = keras.preprocessing.sequence.pad_sequences(train_data, 
                                                        value = word_index["<PAD>"], 
                                                        padding = 'post', 
                                                        maxlen = 256)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, 
                                                       value=word_index["<PAD>"], 
                                                       padding='post', 
                                                       maxlen=256)

vocab_size = 10000
model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation=tf.nn.relu))
model.add(keras.layers.Dense(1, activation=tf.nn.sigmoid))

#model.summary()

# %%
#제공 실습 코드

import numpy as np
import tensorflow as tf
from tensorflow import keras

#학습용 데이터
imdb = keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
#print("Training entries: {}, labels: {}".format(len(train_data), len(train_labels)))
#print(train_data[0])

# A dictionary mapping words to an integer index
word_index = imdb.get_word_index()

# The first indices are reserved
word_index = {k:(v+3) for k,v in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2  # unknown
word_index["<UNUSED>"] = 3

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

decode_review(train_data[4])

train_data = keras.preprocessing.sequence.pad_sequences(train_data,
                                                        value=word_index["<PAD>"],
                                                        padding='post',
                                                        maxlen=256)

test_data = keras.preprocessing.sequence.pad_sequences(test_data,
                                                       value=word_index["<PAD>"],
                                                       padding='post',
                                                       maxlen=256)

#print(len(train_data[0]), len(test_data[0]))
#print(train_data[0])

# input shape is the vocabulary count used for the movie reviews (10,000 words)
vocab_size = 10000

model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation=tf.nn.relu))
model.add(keras.layers.Dense(1, activation=tf.nn.sigmoid))

model.summary()

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

#모델을 평가할 test 데이터에 대한 정의 (1만을 기준으로 학습과 평가 수행)

x_val = train_data[:10000]
partial_x_train = train_data[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=40,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)


results = model.evaluate(test_data, test_labels)
print(results)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d_6 ( (None, 16)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6923 - accuracy: 0.5539 - val_loss: 0.6908 - val_accuracy: 0.4966
# Epoch 2/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6872 - accuracy: 0.5736 - val_loss: 0.6837 - val_accuracy: 0.6303
# Epoch 3/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6756 - accuracy: 0.6767 - val_loss: 0.6686 - val_accuracy: 0.7227
# Epoch 4/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6537 - accuracy: 0.7381 - val_loss: 0.6433 - val_accuracy: 0.7492
# Epoch 5/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6201 - accuracy: 0.7771 - val_loss: 0.6082 - val_accuracy: 0.7729
# Epoch 6/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.5771 - accuracy: 0.8075 - val_loss: 0.5662 - val_accuracy: 0.7975
# Epoch 7/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5285 - accuracy: 0.8306 - val_loss: 0.5207 - val_accuracy: 0.8215
# Epoch 8/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4792 - accuracy: 0.8509 - val_loss: 0.4774 - val_accuracy: 0.8345
# Epoch 9/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4331 - accuracy: 0.8651 - val_loss: 0.4394 - val_accuracy: 0.8462
# Epoch 10/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3935 - accuracy: 0.8760 - val_loss: 0.4081 - val_accuracy: 0.8534
# Epoch 11/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3599 - accuracy: 0.8829 - val_loss: 0.3826 - val_accuracy: 0.8599
# Epoch 12/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3314 - accuracy: 0.8927 - val_loss: 0.3623 - val_accuracy: 0.8661
# Epoch 13/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3078 - accuracy: 0.8969 - val_loss: 0.3469 - val_accuracy: 0.8676
# Epoch 14/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2884 - accuracy: 0.9036 - val_loss: 0.3348 - val_accuracy: 0.8714
# Epoch 15/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2702 - accuracy: 0.9076 - val_loss: 0.3234 - val_accuracy: 0.8769
# Epoch 16/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2550 - accuracy: 0.9133 - val_loss: 0.3153 - val_accuracy: 0.8784
# Epoch 17/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2415 - accuracy: 0.9181 - val_loss: 0.3095 - val_accuracy: 0.8779
# Epoch 18/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2296 - accuracy: 0.9221 - val_loss: 0.3027 - val_accuracy: 0.8795
# Epoch 19/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2177 - accuracy: 0.9259 - val_loss: 0.2984 - val_accuracy: 0.8830
# Epoch 20/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.2071 - accuracy: 0.9293 - val_loss: 0.2950 - val_accuracy: 0.8825
# Epoch 21/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1976 - accuracy: 0.9333 - val_loss: 0.2916 - val_accuracy: 0.8831
# Epoch 22/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1888 - accuracy: 0.9371 - val_loss: 0.2895 - val_accuracy: 0.8837
# Epoch 23/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1803 - accuracy: 0.9418 - val_loss: 0.2886 - val_accuracy: 0.8843
# Epoch 24/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1724 - accuracy: 0.9452 - val_loss: 0.2867 - val_accuracy: 0.8837
# Epoch 25/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1647 - accuracy: 0.9481 - val_loss: 0.2872 - val_accuracy: 0.8857
# Epoch 26/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1582 - accuracy: 0.9507 - val_loss: 0.2875 - val_accuracy: 0.8834
# Epoch 27/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1518 - accuracy: 0.9539 - val_loss: 0.2871 - val_accuracy: 0.8846
# Epoch 28/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1453 - accuracy: 0.9558 - val_loss: 0.2878 - val_accuracy: 0.8846
# Epoch 29/40
# 30/30 [==============================] - 0s 10ms/step - loss: 0.1395 - accuracy: 0.9582 - val_loss: 0.2898 - val_accuracy: 0.8853
# Epoch 30/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1341 - accuracy: 0.9595 - val_loss: 0.2896 - val_accuracy: 0.8866
# Epoch 31/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1283 - accuracy: 0.9634 - val_loss: 0.2911 - val_accuracy: 0.8859
# Epoch 32/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1234 - accuracy: 0.9647 - val_loss: 0.2935 - val_accuracy: 0.8852
# Epoch 33/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1182 - accuracy: 0.9675 - val_loss: 0.2948 - val_accuracy: 0.8856
# Epoch 34/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1138 - accuracy: 0.9689 - val_loss: 0.2972 - val_accuracy: 0.8851
# Epoch 35/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1094 - accuracy: 0.9703 - val_loss: 0.2995 - val_accuracy: 0.8856
# Epoch 36/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1048 - accuracy: 0.9715 - val_loss: 0.3026 - val_accuracy: 0.8842
# Epoch 37/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1010 - accuracy: 0.9741 - val_loss: 0.3048 - val_accuracy: 0.8838
# Epoch 38/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0968 - accuracy: 0.9747 - val_loss: 0.3079 - val_accuracy: 0.8834
# Epoch 39/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0928 - accuracy: 0.9761 - val_loss: 0.3112 - val_accuracy: 0.8838
# Epoch 40/40
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0893 - accuracy: 0.9769 - val_loss: 0.3152 - val_accuracy: 0.8825
# 782/782 [==============================] - 0s 453us/step - loss: 0.3347 - accuracy: 0.8712
# [0.33465734124183655, 0.8712400197982788]
